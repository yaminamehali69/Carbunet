# %% [markdown]
# ### 1.Importation des packages

# %%
import pandas as pd 
import numpy as np # calculs mathématiques en Python
import scipy.stats as st  ## statistiques avancées.
from sqlalchemy import create_engine
! pip install  scipy sqlalchemy 
## Chef d'orchrestre de la BDD , elle permet de facilité la gestion des connexions;Au lieu de gérer la connexion à la main de façon complexe, il permet de transformer tes résultats SQL directement en tableaux (DataFrames) que Pandas peut lire facilement. 
! pip install scipy 
### bibliothèque pour les calculs scientifiques complexes.
! pip install pymysql 
# Biblitothèque qui sert a python pour communique avec une BDD mysql ,C'est le traducteur qui permet à ton script Python d'envoyer tes requêtes SQL, c'est sont j'ai écrit pour power bi sur Dbeaver avec mariadb

# %% [markdown]
# ### 2.Importation data

# %%
# 1. Télécharger automatiquement le fichier depuis data.gouv ===
url = "https://www.data.gouv.fr/api/1/datasets/r/edd67f5b-46d0-4663-9de9-e5db1c880160"
carburant_prix = pd.read_csv(url, sep=';', low_memory=False)

# %% [markdown]
# ### 3.Nettoyage des données avant traitement
